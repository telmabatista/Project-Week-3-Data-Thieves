# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize
import json
from flatten_json import flatten

# %%
with open('ticket.json') as f:
   d = json.load(f)

multi = []; inner = {}

def recursive_extract(i):
    global multi, inner

    if type(i) is list:
        if len(i) == 1:
            for k,v in i[0].items():
                if type(v) in [list, dict]:
                    recursive_extract(v)
                else:                
                    inner[k] = v
        else:
            multi = i

    if type(i) is dict:
        for k,v in i.items():
            if type(v) in [list, dict]:
                recursive_extract(v)
            else:                
                inner[k] = v

recursive_extract(d["_embedded"])

data_dict = []
for i in multi:    
    tmp = inner.copy()
    tmp.update(i)
    data_dict.append(tmp)


dict_flat = [flatten(d) for d in data_dict]

df = pd.DataFrame(dict_flat)
df.head()
# Out:
#                                                 name   type                id  \
# 0                                             Eagles  event     G5vYZ4VqWuxjo
# 1                                             Eagles  event    vvG1YZ4VLloAHj
# 2  Hotel California Tour - LaneOne Upgrade Packag...  event  vv170Z4VGkR9pJLo
# 3  Hotel California Tour - LaneOne Upgrade Packag...  event  vv170Z4VGkR9_kL-
# 4  Hotel California Tour - LaneOne Upgrade Packag...  event     G5vYZ4VR96IJL
#
#     test                                                url locale  \
# 0  False  https://www.ticketmaster.com/eagles-san-franci...  en-us
# 1  False  https://www.ticketmaster.com/eagles-dallas-tex...  en-us
# 2  False  https://www.ticketmaster.com/hotel-california-...  en-us
# 3  False  https://www.ticketmaster.com/hotel-california-...  en-us
# 4  False  https://www.ticketmaster.com/hotel-california-...  en-us
#
#   images_0_ratio                                       images_0_url  \
# ...

# %%
df = df.dropna(axis="columns")
df.head()
# Out:
#                                                 name   type                id  \
# 0                                             Eagles  event     G5vYZ4VqWuxjo
# 1                                             Eagles  event    vvG1YZ4VLloAHj
# 2  Hotel California Tour - LaneOne Upgrade Packag...  event  vv170Z4VGkR9pJLo
# 3  Hotel California Tour - LaneOne Upgrade Packag...  event  vv170Z4VGkR9_kL-
# 4  Hotel California Tour - LaneOne Upgrade Packag...  event     G5vYZ4VR96IJL
#
#     test                                                url locale  \
# 0  False  https://www.ticketmaster.com/eagles-san-franci...  en-us
# 1  False  https://www.ticketmaster.com/eagles-dallas-tex...  en-us
# 2  False  https://www.ticketmaster.com/hotel-california-...  en-us
# 3  False  https://www.ticketmaster.com/hotel-california-...  en-us
# 4  False  https://www.ticketmaster.com/hotel-california-...  en-us
#
#   images_0_ratio                                       images_0_url  \
# ...

# %%
df = df.drop(['sales_public_startDateTime', 'sales_public_startTBD', 'sales_public_endDateTime','test','dates_start_localTime','dates_start_dateTime','dates_start_dateTBD','dates_start_dateTBA','dates_start_timeTBA','dates_start_noSpecificTime','dates_timezone','dates_spanMultipleDays','classifications_0_primary','classifications_0_segment_id','classifications_0_genre_id','classifications_0_subGenre_id','classifications_0_type_id','classifications_0_subType_id','classifications_0_family','_links_self_href','_links_attractions_0_href','_links_venues_0_href','_embedded_venues_0_id','_embedded_venues_0_test','_embedded_venues_0_url','_embedded_venues_0_locale','_embedded_venues_0_images_0_url','_embedded_venues_0_images_0_width','_embedded_venues_0_
','_embedded_attractions_0_classifications_0_type_name','_embedded_attractions_0_classifications_0_subType_id','_embedded_attractions_0_classifications_0_subType_name','_embedded_attractions_0_classifications_0_family','_embedded_attractions_0_upcomingEvents__total','_embedded_attractions_0_upcomingEvents_ticketmaster','_embedded_attractions_0__links_self_href','images_0_ratio', 'images_0_url', 'images_0_width', 'images_0_height', 'images_0_fallback', 'images_1_ratio', 'images_1_url', 'images_1_width', 'images_1_height', 'images_1_fallback', 'images_2_ratio', 'images_2_url', 'images_2_width', 'images_2_height', 'images_2_fallback', 'images_3_ratio', 'images_3_url', 'images_3_width', 'images_3_height', 'images_3_fallback', 'images_4_ratio', 'images_4_url', 'images_4_width', 'images_4_height', 'images_4_fallback', 'images_5_ratio', 'images_5_url', 'images_5_width', 'images_5_height', 'images_5_fallback', 'images_6_ratio', 'images_6_url', 'images_6_width', 'images_6_height', 'images_6_fallback', 'images_7_ratio', 'images_7_url', 'images_7_width', 'images_7_height', 'images_7_fallback', 'images_8_ratio', 'images_8_url', 'images_8_width', 'images_8_height', 'images_8_fallback', 'images_9_ratio', 'images_9_url', 'images_9_width', 'images_9_height', 'images_9_fallback'],axis=1)

df.head()
# Out:
#                                                 name   type                id  \
# 0                                             Eagles  event     G5vYZ4VqWuxjo
# 1                                             Eagles  event    vvG1YZ4VLloAHj
# 2  Hotel California Tour - LaneOne Upgrade Packag...  event  vv170Z4VGkR9pJLo
# 3  Hotel California Tour - LaneOne Upgrade Packag...  event  vv170Z4VGkR9_kL-
# 4  Hotel California Tour - LaneOne Upgrade Packag...  event     G5vYZ4VR96IJL
#
#                                                  url locale  \
# 0  https://www.ticketmaster.com/eagles-san-franci...  en-us
# 1  https://www.ticketmaster.com/eagles-dallas-tex...  en-us
# 2  https://www.ticketmaster.com/hotel-california-...  en-us
# 3  https://www.ticketmaster.com/hotel-california-...  en-us
# 4  https://www.ticketmaster.com/hotel-california-...  en-us
#
#   dates_start_localDate dates_status_code classifications_0_segment_name  \
# ...

# %%
#df.head()

name_columns = ["name","type","id","url","locale","date","date_status","segment","genre","subgenre","type","subtype","price_type","currency","min_price","max_price","venue_name","venue_type","venue_timezone","city","country","country_code"]

df.columns = name_columns

df.head()
# Out:
#                                                 name   type                id  \
# 0                                             Eagles  event     G5vYZ4VqWuxjo
# 1                                             Eagles  event    vvG1YZ4VLloAHj
# 2  Hotel California Tour - LaneOne Upgrade Packag...  event  vv170Z4VGkR9pJLo
# 3  Hotel California Tour - LaneOne Upgrade Packag...  event  vv170Z4VGkR9_kL-
# 4  Hotel California Tour - LaneOne Upgrade Packag...  event     G5vYZ4VR96IJL
#
#                                                  url locale        date  \
# 0  https://www.ticketmaster.com/eagles-san-franci...  en-us  2020-10-03
# 1  https://www.ticketmaster.com/eagles-dallas-tex...  en-us  2020-10-21
# 2  https://www.ticketmaster.com/hotel-california-...  en-us  2020-09-25
# 3  https://www.ticketmaster.com/hotel-california-...  en-us  2020-09-26
# 4  https://www.ticketmaster.com/hotel-california-...  en-us  2020-10-02
#
# ...
