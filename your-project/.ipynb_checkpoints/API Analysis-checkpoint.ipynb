# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %% [markdown]
# ## Ticketmaster Data

# %%
df = pd.read_csv("ticket_df.csv")

#Eliminating rows that don't have prices
df = df[df['min_price'].notna()]

#Adding new column which is the average of price (min and max)
df["average_price_eur"] = df[["min_price_eur","max_price_eur"]].mean(axis=1)

df.head()
# Out:
#      name   type                 id  \
# 0  Eagles  event      G5vzZ4g6yyBHk
# 1  Eagles  event  vv1AkZAq8GkezVfHD
# 2  Eagles  event     vvG1YZ4VLloAHj
# 3  Eagles  event      G5vYZ4VqWuxjo
# 4  Eagles  event      G5vzZ4g6yzQHe
#
#                                                  url locale        date  \
# 0  https://www.ticketmaster.com/eagles-denver-col...  en-us  2020-09-18
# 1  https://www.ticketmaster.com/eagles-saint-paul...  en-us  2020-10-16
# 2  https://www.ticketmaster.com/eagles-dallas-tex...  en-us  2020-10-21
# 3  https://www.ticketmaster.com/eagles-san-franci...  en-us  2020-10-03
# 4  https://www.ticketmaster.com/eagles-denver-col...  en-us  2020-09-19
#
#    date_status segment genre subgenre  ... max_price  \
# 0  rescheduled   Music  Rock      Pop  ...     750.0
# 1  rescheduled   Music  Rock      Pop  ...     767.0
# 2  rescheduled   Music  Rock      Pop  ...     750.0
# 3  rescheduled   Music  Rock      Pop  ...     750.0
# 4  rescheduled   Music  Rock      Pop  ...     750.0
#
#                  venue_name venue_type       venue_timezone           city  \
# 0              Pepsi Center      venue       America/Denver         Denver
# 1        Xcel Energy Center      venue      America/Chicago     Saint Paul
# 2  American Airlines Center      venue      America/Chicago         Dallas
# 3              Chase Center      venue  America/Los_Angeles  San Francisco
# 4              Pepsi Center      venue       America/Denver         Denver
#
#                     country country_code min_price_eur max_price_eur  \
# 0  United States Of America           US    116.911365    679.717238
# 1  United States Of America           US    114.192496    695.124162
# 2  United States Of America           US    116.911365    679.717238
# 3  United States Of America           US    116.911365    679.717238
# 4  United States Of America           US    116.911365    679.717238
#
#   average_price_eur
# 0        398.314301
# 1        404.658329
# 2        398.314301
# 3        398.314301
# 4        398.314301
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Country Indicators

# %%
stat = pd.read_excel("country_data.xls")

"""stat.head().columns
'Unnamed: 0',
       'Audio-visual, photographic and information processing equipment',
       'Other major durables for recreation and culture',
       'Other recreational items and equipment, gardens and pets',
       'Recreational and cultural services',
       'Newspapers, books and stationary', 'Population', 'Tourism Arrivals',
       'GPD pp'],"""

column_names = ["country_code","Equipment","Durables","Other items","Services","Newspapers and books",
                "Population","Tourism Arrivals","GDP_pp"]

stat.columns = column_names

#The expenditure in recreation was by total population, so we divide it by the population to get the value per capita
stat[["Equipment","Durables","Other items","Services","Newspapers and books"]] = stat[["Equipment","Durables","Other items","Services","Newspapers and books"]].div(stat.Population, axis=0)
stat.head()

#Since the dataframe is in usd, we need to transform it into eur
exchange = requests.get("https://api.exchangeratesapi.io/latest")
exchange = exchange.json()
exchange = pd.DataFrame(json_normalize(exchange).T)

stat[["Equipment","Durables","Other items","Services","Newspapers and books","GDP_pp"]] = stat[["Equipment","Durables","Other items","Services","Newspapers and books","GDP_pp"]].div(exchange.loc["rates.USD"][0], axis=0)

#The Total column is the column that agregates all types of expenditure with recreation and culture
stat["Culture Expenditure"] = stat["Equipment"] + stat["Durables"] + stat["Other items"] + stat["Services"] + stat["Newspapers and books"]

#Changing to the same country codes 
stat["country_code"] = ["US","CA","GB","IE","MX","NZ"]
stat.head(7)
# Out:
#   country_code   Equipment    Durables  Other items    Services  \
# 0           US  974.942753  183.595670   810.542032  954.495839
# 1           CA  235.988760  155.825162   433.068303  792.340905
# 2           GB  453.680633  266.538640   764.247708  929.806803
# 3           IE   38.114283    1.619941   236.947121  736.514391
# 4           MX   97.568401    4.232093    37.091409   71.305662
# 5           NZ  207.906166   95.276760   264.247799  696.204109
#
#    Newspapers and books   Population  Tourism Arrivals        GDP_pp  \
# 0            275.905924  327200000.0          79745920  56910.096067
# 1            120.562080   37590000.0          21134000  41900.489396
# 2            199.794036   66440000.0          36316000  38919.612108
# 3            142.254445    4830000.0          10926000  71421.424687
# 4             25.713823  129200000.0          41313000   8766.902302
# 5            225.582371    4794000.0           3709967  38014.591263
#
#    Culture Expenditure
# 0          3199.482218
# 1          1737.785209
# 2          2614.067820
# 3          1155.450182
# 4           235.911387
# 5          1489.217205

# %% [markdown]
# ## Merged Dataframe

# %%
df.groupby(["country_code"]).count()

merged = pd.merge(df,stat, on="country_code")

merged.head()

print(list(merged.columns))
# Out:
# ['name', 'type', 'id', 'url', 'locale', 'date', 'date_status', 'segment', 'genre', 'subgenre', 'type.1', 'subtype', 'price_type', 'currency', 'min_price', 'max_price', 'venue_name', 'venue_type', 'venue_timezone', 'city', 'country', 'country_code', 'min_price_eur', 'max_price_eur', 'average_price_eur', 'Equipment', 'Durables', 'Other items', 'Services', 'Newspapers and books', 'Population', 'Tourism Arrivals', 'GDP_pp', 'Culture Expenditure']

# %%
#Choosing price variable for correlation

price = input("Choose between 'min_price_eur','max_price_eur','average_price_eur': ")
# Out:
# Choose between 'min_price_eur','max_price_eur','average_price_eur': average_price_eur

# %%
merged = merged.groupby(["Tourism Arrivals","Culture Expenditure","Population","GDP_pp"])[price].mean()
merged = merged.to_frame()
merged = merged.reset_index()

# %%
merged.head()
# Out:
#    Tourism Arrivals  Culture Expenditure   Population        GDP_pp  \
# 0           3709967          1489.217205    4794000.0  38014.591263
# 1          10926000          1155.450182    4830000.0  71421.424687
# 2          21134000          1737.785209   37590000.0  41900.489396
# 3          36316000          2614.067820   66440000.0  38919.612108
# 4          41313000           235.911387  129200000.0   8766.902302
#
#    average_price_eur
# 0          43.681843
# 1          75.091606
# 2         113.640063
# 3         342.350956
# 4          97.124514

# %%
series = merged[merged.columns[0:4]].apply(lambda x: x.corr(merged[price]))

print(series)
# Out:
# Tourism Arrivals       0.597765
# Culture Expenditure    0.732975
# Population             0.437632
# GDP_pp                 0.053230
# dtype: float64

# %%
scatter_matrix(merged, figsize=(6,6))
plt.show()
